# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import pandas as pd
import numpy as np

# %%
path = 'C:\\Users\\R\\Desktop\\MASAI\\PROJECT\\chromedriver.exe'

# %%
browser = webdriver.Chrome(path)
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_2288\217355859.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(path)

# %%
link = 'https://www.instahyre.com/search-jobs?company_size=0&isLandingPage=true&location=Anywhere+in+India&offset=0&search=true'
browser.get(link)

# %%
parent = browser.current_window_handle

# %%
Job_list = []

for page in range(50):
    view_button = browser.find_elements(By.ID, "interested-btn")
    for i in view_button:
        i.click()
        time.sleep(3)
        browser.switch_to.window(browser.window_handles[-1])

        try:
            designation = browser.find_element(By.XPATH, ".//h1[@class = 'ng-binding']").text
        except:
            designation = ''
        try:
            company_name = browser.find_element(By.XPATH, "//*[@id='floating-header']/div[1]/h2").text
        except:
            company_name = ''
        try:
            location = browser.find_element(By.XPATH, ".//*[@id='floating-header']/div[1]/div/span[1]").text
        except:
            location = ''
        try:
            estab_year = browser.find_element(By.XPATH, "(//div[@class='ng-binding ng-scope'])[1]").text
        except:
            estab_year = ''
        try:
            employees_count =  browser.find_element(By.XPATH, "(//div[@class='ng-binding ng-scope'])[2]").text
        except:
            employees_count = ''
        try:
            job_description =  browser.find_element(By.XPATH, ".//p[@class='ng-binding']").text
        except:
            job_description = ''
        try:
            skills = browser.find_element(By.XPATH, "//*[@id='job-skills-description']").text
        except:
            skills = ''
        try:
            hr_name = browser.find_element(By.CLASS_NAME, "rec-info").text
        except:
            hr_name = ''
        try:
            experience_req = browser.find_element(By.XPATH, "//*[@id='floating-header']/div[1]/div/span[2]").text
        except:
            experience_req = ''
        try:
            emp_overall_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[1]/div[2]/span[2]').text
        except:
            emp_overall_rating = ''
        try:
            emp_wl_bal_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[2]/div[2]/span[2]').text
        except:
            emp_wl_bal_rating = ''
        try:
            emp_salary_n_benefits_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[3]/div[2]/span[2]').text
        except:
            emp_salary_n_benefits_rating = ''
        try:
            emp_comp_culture_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[4]/div[2]/span[2]').text
        except:
            emp_comp_culture_rating = ''
        try:
            emp_career_growth_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[5]/div[2]/span[2]').text
        except:
            emp_career_growth_rating = ''
        try:
            emp_diversity_n_inclusion_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[6]/div[2]/span[2]').text
        except:
            emp_diversity_n_inclusion_rating = ''
        try:
            emp_likely_to_recomm_rating = browser.find_element(By.XPATH, '//*[@id="employer-profile"]/div[2]/div/div/div[1]/div[4]/div/div[7]/div[2]/span[2]').text
        except:
            emp_likely_to_recomm_rating = ''

        job_details = {'designation':designation, 'company_name':company_name,'location':location, 'estab_year':estab_year,
                       'employees_count':employees_count, 'job_description': job_description, 'skills':skills, 'hr_name':hr_name,
                      'experience_req':experience_req, 'emp_overall_rating':emp_overall_rating,'emp_wl_bal_rating':emp_wl_bal_rating,
                      'emp_salary_n_benefits_rating':emp_salary_n_benefits_rating, 'emp_comp_culture_rating':emp_comp_culture_rating,
                      'emp_career_growth_rating':emp_career_growth_rating,'emp_diversity_n_inclusion_rating':emp_diversity_n_inclusion_rating,
                      'emp_likely_to_recomm_rating':emp_likely_to_recomm_rating}

        Job_list.append(job_details)
        browser.close()
        browser.switch_to.window(parent)
        
    next_botton = browser.find_element(By.XPATH, './/*[@id="job-function-page"]/div[2]/div/div[1]/div[11]/li[12]')
    next_botton.click()
    time.sleep(4)

# %%
df1 = pd.DataFrame(Job_list)
df1
# Out:
#                                           designation company_name  \
# 0                    Business Systems Analyst (Drive)       Google
# 1                            Technical Writer (Drive)     Hugosave
# 2                               AEM Developer (Drive)  LTIMindtree
# 3             Big Data - Java Spark Developer (Drive)  LTIMindtree
# 4                  Informatica IICS Developer (Drive)  LTIMindtree
# 5                        Oracle - UFT Testing (Drive)  LTIMindtree
# 6                          PL / SQL Developer (Drive)  LTIMindtree
# 7                         Snowflake Developer (Drive)  LTIMindtree
# 8                         Key Account Manager (Drive)        Park+
# 9                             Sales Executive (Drive)        Park+
# 10             Sales / Senior Sales Associate (Drive)    Ivy Homes
# 11             .NET Azure Fullstack Developer (Drive)  LTIMindtree
# 12                         Automation Testing (Drive)  LTIMindtree
# 13                 Azure Databricks Developer (Drive)  LTIMindtree
# 14                               Azure DevOps (Drive)  LTIMindtree
# 15                              GCP Developer (Drive)  LTIMindtree
# 16                         React.js Developer (Drive)  LTIMindtree
# 17                       Regional Supply Head (Drive)       Treebo
# 18  Territory Sales Manager (Gujarat, Chandigarh, ...       Treebo
# 19  Territory Sales Manager (Jamshedpur, Kolkata, ...       Treebo
#
#                            location       estab_year  \
# 0                         Hyderabad  Founded in 1998
# 1                         Hyderabad  Founded in 2019
# 2      Bangalore, Hyderabad, Mumbai  Founded in 1996
# 3        Bangalore, Chennai, Mumbai  Founded in 1996
# 4      Bangalore, Hyderabad, Mumbai  Founded in 1996
# 5                            Mumbai  Founded in 1996
# 6      Bangalore, Hyderabad, Mumbai  Founded in 1996
# 7        Bangalore, Chennai, Mumbai  Founded in 1996
# 8                           Gurgaon  Founded in 2019
# 9                   Jaipur, Lucknow  Founded in 2019
# 10                        Bangalore  Founded in 2021
# 11                           Mumbai  Founded in 1996
# 12                        Bangalore  Founded in 1996
# 13       Bangalore, Chennai, Mumbai  Founded in 1996
# 14                           Mumbai  Founded in 1996
# 15       Bangalore, Chennai, Mumbai  Founded in 1996
# 16                           Mumbai  Founded in 1996
# 17                  Kolkata, Mumbai  Founded in 2015
# 18  Chandigarh, Gandhinagar, Indore  Founded in 2015
# 19      Jamshedpur, Kolkata, Ranchi  Founded in 2015
#
#              employees_count  \
# 0   More than 1000 employees
# 1          10 - 50 employees
# 2   More than 1000 employees
# 3   More than 1000 employees
# 4   More than 1000 employees
# 5   More than 1000 employees
# 6   More than 1000 employees
# 7   More than 1000 employees
# 8        200 - 500 employees
# 9        200 - 500 employees
# 10          0 - 10 employees
# 11  More than 1000 employees
# 12  More than 1000 employees
# 13  More than 1000 employees
# 14  More than 1000 employees
# 15  More than 1000 employees
# 16  More than 1000 employees
# 17       200 - 500 employees
# 18       200 - 500 employees
# 19       200 - 500 employees
#
#                                       job_description  \
# 0   Function: Data Science and Analysis → Data Ana...
# 1   Function: IT Operations and Support → Technica...
# 2   Function: Software Engineering → Other Softwar...
# 3   Function: Software Engineering → Big Data / DW...
# 4   Function: Software Engineering → Big Data / DW...
# 5          Function: Software Engineering → QA / SDET
# 6   Function: IT Operations and Support → Database...
# 7   Function: Software Engineering → Big Data / DW...
# 8   Function: Sales and Business → Sales / Busines...
# 9   Function: Sales and Business → Sales / Busines...
# 10  Function: Sales and Business → Sales / Busines...
# 11  Function: Software Engineering → Backend Devel...
# 12         Function: Software Engineering → QA / SDET
# 13  Function: Software Engineering → Big Data / DW...
# 14  Function: IT Operations and Support → DevOps /...
# 15  Function: Software Engineering → Big Data / DW...
# 16  Function: Software Engineering → Frontend Deve...
# 17  Function: Sales and Business → Sales / Busines...
# 18  Function: Sales and Business → Sales / Busines...
# 19  Function: Sales and Business → Sales / Busines...
#
#                                                skills  \
# 0   Finance\nMarketing\nMicrosoft Excel\nProduct M...
# 1                 Postman\nSwagger\nTechnical Writing
# 2                      Adobe Experience Manager (AEM)
# 3   Amazon Redshift\nBig Data\nData Analysis\nData...
# 4                Informatica\nInformatica PowerCenter
# 5                             Automation Testing\nQTP
# 6                                  Oracle RAC\nPL-SQL
# 7               Data Warehousing\nETL\nSQL\nSnowflake
# 8   Channel Sales\nCorporate Sales\nKey Account Ma...
# 9               Channel Sales\nCorporate Sales\nSales
# 10       Business Development\nLead Generation\nSales
# 11  .NET\nASP.NET\nAngular\nAzure\nBootstrap\nC#\n...
# 12  API Testing\nAppium\nCucumber\nJMeter\nJava\nM...
# 13  Databricks\nHadoop\nSpark\nETL\nPySpark\nSnowf...
# 14  Ansible\nAzure\nAzure DevOps Server\nCI - CD\n...
# 15           BigQuery\nGoogle Cloud\nPython\nDataflow
# 16            CSS\nHTML\nJavaScript\nReact.js\njQuery
# 17  Business Development\nChannel Sales\nProfit an...
# 18  Business Development\nChannel Sales\nCorporate...
# 19  Business Development\nCorporate Sales\nDirect ...
#
#                                               hr_name experience_req  \
# 0     Aneesh Vikram\nRecruiting Specialist\nat Google      5-9 Years
# 1   Neha Khaitan\nTalent Acquisition Specialist\na...     7-10 Years
# 2                  Akshata\nRecruiter\nat LTIMindtree      3-6 Years
# 3                  Akshata\nRecruiter\nat LTIMindtree      5-6 Years
# 4                  Akshata\nRecruiter\nat LTIMindtree      5-6 Years
# 5                  Akshata\nRecruiter\nat LTIMindtree      3-5 Years
# 6                  Akshata\nRecruiter\nat LTIMindtree      5-6 Years
# 7                  Akshata\nRecruiter\nat LTIMindtree      5-6 Years
# 8                   Hitesh Gupta\nRecruiter\nat Park+      0-1 Years
# 9                   Hitesh Gupta\nRecruiter\nat Park+      1-3 Years
# 10            Pritam Thakur\nCo-Founder\nat Ivy Homes      1-5 Years
# 11                 Akshata\nRecruiter\nat LTIMindtree      3-6 Years
# 12                 Akshata\nRecruiter\nat LTIMindtree      5-6 Years
# 13                 Akshata\nRecruiter\nat LTIMindtree      5-6 Years
# 14                 Akshata\nRecruiter\nat LTIMindtree      4-6 Years
# 15                 Akshata\nRecruiter\nat LTIMindtree      5-6 Years
# 16                 Akshata\nRecruiter\nat LTIMindtree      3-6 Years
# 17  Advita Karkera\nTalent Acquisition Executive\n...      5-8 Years
# 18  Advita Karkera\nTalent Acquisition Executive\n...      2-6 Years
# 19  Advita Karkera\nTalent Acquisition Executive\n...      2-6 Years
#
#    emp_overall_rating emp_wl_bal_rating emp_salary_n_benefits_rating  \
# 0                 4.1               4.3                          4.4
# 1
# 2                   4               3.8                          3.4
# 3                   4               3.8                          3.4
# 4                   4               3.8                          3.4
# 5                   4               3.8                          3.4
# 6                   4               3.8                          3.4
# 7                   4               3.8                          3.4
# 8                 3.8               3.4                          3.6
# 9                 3.8               3.4                          3.6
# 10
# 11                  4               3.8                          3.4
# 12                  4               3.8                          3.4
# 13                  4               3.8                          3.4
# 14                  4               3.8                          3.4
# 15                  4               3.8                          3.4
# 16                  4               3.8                          3.4
# 17                3.4               3.4                          3.1
# 18                3.4               3.4                          3.1
# 19                3.4               3.4                          3.1
#
#    emp_comp_culture_rating emp_career_growth_rating  \
# 0                      4.4                      4.3
# 1
# 2                        4                      3.9
# 3                        4                      3.9
# 4                        4                      3.9
# 5                        4                      3.9
# 6                        4                      3.9
# 7                        4                      3.9
# 8                      3.6                      3.9
# 9                      3.6                      3.9
# 10
# 11                       4                      3.9
# 12                       4                      3.9
# 13                       4                      3.9
# 14                       4                      3.9
# 15                       4                      3.9
# 16                       4                      3.9
# 17                     3.6                      3.3
# 18                     3.6                      3.3
# 19                     3.6                      3.3
#
#    emp_diversity_n_inclusion_rating emp_likely_to_recomm_rating
# 0                               4.4                         4.5
# 1
# 2                                 4                         4.3
# 3                                 4                         4.3
# 4                                 4                         4.3
# 5                                 4                         4.3
# 6                                 4                         4.3
# 7                                 4                         4.3
# 8                               3.7                         3.6
# 9                               3.7                         3.6
# 10
# 11                                4                         4.3
# 12                                4                         4.3
# 13                                4                         4.3
# 14                                4                         4.3
# 15                                4                         4.3
# 16                                4                         4.3
# 17                              4.4                           3
# 18                              4.4                           3
# 19                              4.4                           3

# %%
df1.to_csv("Job_details500.csv")
